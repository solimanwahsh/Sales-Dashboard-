# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd

# %%
url="https://wuzzuf.net/search/jobs/?a=hpb&q=Data%20Scientist&start=0"

# %%
req=requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.text,"html")  ## to convert the data into text

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
#print(soup.prettify())

# %% [markdown]
# # Find and Find All

# %%
icon=soup.findAll("div",class_="css-1gatmva e1v1l3u10")             # text dont work with find_all

# %%
len(icon)
# Out:
# 15

# %%
jtitle=icon[0].findAll("h2",class_="css-m604qf")

# %%
jtitle[0].text
# Out:
# 'Data Scientist'

# %%
cname=icon[0].findAll("a",class_="css-17s97q8")

# %%
cname[0].text
# Out:
# 'Atribs Metscon -'

# %%
region=icon[0].findAll("span",class_="css-5wys0k")

# %%
region[0].text
# Out:
# 'Abu Dhabi, United Arab Emirates '

# %%
ttime=icon[0].findAll("span",class_="css-1ve4b75 eoyjyou0")

# %%
ttime[0].text
# Out:
# 'Full Time'

# %%
f=open("C:/Users/FRIENDS/Downloads/wuzzf.tsv","w")
headers='Jop Title, Company Name ,Region ,Tyepe Time\n'

# %%
f.write(headers)
# Out:
# 44

# %%
for ico in icon:
    
    jtitle=ico.findAll("h2",class_="css-m604qf")
    Jop_Title=jtitle[0].text
    
    cname=ico.findAll("a",class_="css-17s97q8")
    Company_Name=cname[0].text
    
    region=ico.findAll("span",class_="css-5wys0k")
    Region=region[0].text
    
    ttime=ico.findAll("span",class_="css-1ve4b75 eoyjyou0")
    Type_Time=ttime[0].text
    
    #print(Jop_Title)
    # print(Company_Name)
    #print(Region)
    #print(Type_Time)
    #print(Jop_Title +" ,"+ Company_Name +" ,"+ Region +" ,"+ Type_Time)
    #print()
    f.write(Jop_Title +" ,"+ Company_Name +" ,"+ Region +" ,"+ Type_Time + "\n")  
f.close()

# %%
df=pd.read_csv("C:/Users/FRIENDS/Downloads/wuzzf.csv")

# %%
df=pd.DataFrame(df)

# %%
df.head()
# Out:
#   Jop Title ;Company Name ;Region ;Tyepe Time;date;alll
# 0  Data Scientist ;Atribs Metscon - ;Abu Dhabi; U...
# 1  Senior Data Scientist ;Etisalat Egypt - ;Maadi...
# 2  Data Scientist ;Vistas Global - ;Doha; Qatar  ...
# 3  Senior Data Scientist ;Teradata - ;Cairo; Egyp...
# 4  Junior Data Scientist ;Cultiv - ;Cairo; Egypt ...
